# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Exploring the dataset

# %%
nobel = pd.read_csv('/Users/trannguyen/Documents/Python Practices/Nobel/archive.csv')
nobel.head()
# Out:
#    Year    Category                                           Prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           Motivation Prize Share  Laureate ID  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   Laureate Type                     Full Name  Birth Date         Birth City  \
# ...

# %%
# Display the number of (possibly shared) Nobel Prizes handed
# out between 1901 and 2016
display(len(nobel))

# Display the number of prizes won by male and female recipients.
display(nobel['Sex'].value_counts())

# Display the number of prizes won by the top 10 nationalities.
nobel['Birth Country'].value_counts().head(10)
# Out:
# 969
# Male      893
# Female     50
# Name: Sex, dtype: int64
# United States of America    276
# United Kingdom               88
# Germany                      70
# France                       53
# Sweden                       30
# Japan                        29
# Russia                       20
# Netherlands                  19
# Canada                       18
# Italy                        18
# Name: Birth Country, dtype: int64

# %% [markdown]
# It comes as no surprise that Nobel prizes are dominated by male recipients. Not so surprising, perhaps: the most common Nobel laureate between 1901 and 2016 was a man born in the United States of America. But in 1901 all the winners were European. When did the USA start to dominate the Nobel Prize charts?

# %%
nobel['Usa_born_winner'] = nobel['Birth Country'] == 'United States of America'
nobel['Decade'] = (np.floor(nobel['Year']/10)*10).astype(int)
prop_usa_winners = nobel.groupby(['Decade'],as_index = False)['Usa_born_winner'].mean()
prop_usa_winners
# Out:
#     Decade  Usa_born_winner
# 0     1900         0.017241
# 1     1910         0.075000
# 2     1920         0.074074
# 3     1930         0.241935
# 4     1940         0.288889
# 5     1950         0.278481
# 6     1960         0.262500
# 7     1970         0.308411
# 8     1980         0.313131
# 9     1990         0.392523
# 10    2000         0.414286
# 11    2010         0.336735

# %%
sns.set()
plt.rcParams['figure.figsize'] = [11,7]
ax = sns.lineplot(x='Decade',y='Usa_born_winner', data = prop_usa_winners)

#adding %-formatting to the y-axis
from matplotlib.ticker import PercentFormatter
ax.yaxis.set_major_formatter(PercentFormatter(1.0))

# %% [markdown]
# The USA became the dominating winner of the Nobel Prize first in the 1930s and had kept the leading position ever since. But one group that was in the lead from the start, and never seems to let go, are men. Maybe it shouldn't come as a shock that there is some imbalance between how many male and female prize winners there are, but how significant is this imbalance? And is it better or worse within specific prize categories like physics, medicine, literature, etc.?

# %%
nobel['Female_winner'] = nobel['Sex'] == 'Female'
prop_female_winners = nobel.groupby(['Decade','Category'],as_index=False)['Female_winner'].mean()
prop_female_winners
# Out:
#     Decade    Category  Female_winner
# 0     1900   Chemistry       0.000000
# 1     1900  Literature       0.100000
# 2     1900    Medicine       0.000000
# 3     1900       Peace       0.071429
# 4     1900     Physics       0.076923
# ..     ...         ...            ...
# 61    2010   Economics       0.000000
# 62    2010  Literature       0.285714
# 63    2010    Medicine       0.100000
# 64    2010       Peace       0.400000
# 65    2010     Physics       0.000000
#
# [66 rows x 3 columns]

# %%
ax = sns.lineplot(x='Decade',y='Female_winner', hue = 'Category', data = prop_female_winners)
ax.yaxis.set_major_formatter(PercentFormatter(1.0))

# %%
nobel[nobel.Sex == 'Female'].nsmallest(1,'Year')
# Out:
#     Year Category                            Prize  \
# 19  1903  Physics  The Nobel Prize in Physics 1903
#
#                                            Motivation Prize Share  \
# 19  "in recognition of the extraordinary services ...         1/4
#
#     Laureate ID Laureate Type                    Full Name  Birth Date  \
# 19            6    Individual  Marie Curie, née Sklodowska  1867-11-07
#
#    Birth City  ...     Sex Organization Name Organization City  \
# 19     Warsaw  ...  Female               NaN               NaN
#
#    Organization Country  Death Date  Death City Death Country Usa_born_winner  \
# 19                  NaN  1934-07-04  Sallanches        France           False
#
#     Decade  Female_winner
# 19    1900           True
#
# [1 rows x 21 columns]

# %% [markdown]
# For most scientists/writers/activists a Nobel Prize would be the crowning achievement of a long career. But for some people, one is just not enough, and few have gotten it more than once.

# %%
nobel.groupby(['Full Name']).filter(lambda group: len(group) >= 2)
# Out:
#      Year   Category                                           Prize  \
# 19   1903    Physics                 The Nobel Prize in Physics 1903
# 46   1908   Medicine  The Nobel Prize in Physiology or Medicine 1908
# 47   1908   Medicine  The Nobel Prize in Physiology or Medicine 1908
# 63   1911  Chemistry               The Nobel Prize in Chemistry 1911
# 90   1917      Peace                      The Nobel Peace Prize 1917
# ..    ...        ...                                             ...
# 942  2014    Physics                 The Nobel Prize in Physics 2014
# 945  2015  Chemistry               The Nobel Prize in Chemistry 2015
# 946  2015  Chemistry               The Nobel Prize in Chemistry 2015
# 947  2015  Chemistry               The Nobel Prize in Chemistry 2015
# 948  2015  Chemistry               The Nobel Prize in Chemistry 2015
#
#                                             Motivation Prize Share  \
# 19   "in recognition of the extraordinary services ...         1/4
# ...

# %%
nobel['Birth Date'] = pd.to_datetime(nobel['Birth Date'], infer_datetime_format=True, errors='coerce')
nobel['Age'] = nobel['Year'] - nobel['Birth Date'].dt.year

# Plotting the age of Nobel Prize winners
sns.lmplot(x='Year', y='Age', data=nobel,  aspect=2, line_kws={'color' : 'black'})

# %%
sns.lmplot(x='Year', y='Age', row='Category', data=nobel, aspect=2, line_kws={'color' : 'black'})

# %%
# The oldest winner of a Nobel Prize as of 2016
display(nobel.nlargest(1, 'Age'))

# The youngest winner of a Nobel Prize as of 2016
nobel.nsmallest(1, 'Age')
# Out:
#      Year   Category                                              Prize  \
# 825  2007  Economics  The Sveriges Riksbank Prize in Economic Scienc...
#
#                                             Motivation Prize Share  \
# 825  "for having laid the foundations of mechanism ...         1/3
#
#      Laureate ID Laureate Type       Full Name Birth Date Birth City  ...  \
# 825          820    Individual  Leonid Hurwicz 1917-08-21     Moscow  ...
#
#            Organization Name Organization City      Organization Country  \
# 825  University of Minnesota   Minneapolis, MN  United States of America
#
#      Death Date       Death City             Death Country Usa_born_winner  \
# 825  2008-06-24  Minneapolis, MN  United States of America           False
#
#     Decade  Female_winner   Age
# 825   2000          False  90.0
#
# [1 rows x 22 columns]
#      Year Category                       Prize  \
# 940  2014    Peace  The Nobel Peace Prize 2014
#
# ...
